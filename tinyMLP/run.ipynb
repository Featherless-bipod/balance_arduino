# %%
import model as m
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import TensorDataset,DataLoader

# %%
data = pd.read_csv('../data/mnist_test.csv')
data = np.array(data)

np.random.shuffle(data)

# %%
testdata = data[:3000]
traindata = data[3000:]

test_label = testdata[:,0]
test_input = testdata[:,1:]/784 #784 pixels

train_label = traindata[:,0]
train_input = traindata[:,1:]/784

# %%
train_input.shape
train_label.shape
# Out:
# (7000,)

# %%
train_input = torch.tensor(train_input, dtype = torch.float32)
train_label = torch.tensor(train_label, dtype = torch.int64)
test_input = torch.tensor(test_input, dtype = torch.float32)
test_label = torch.tensor(test_label, dtype = torch.int64)

train_dataset = TensorDataset(train_input, train_label)
test_dataset = TensorDataset(test_input, test_label)

train_loader = DataLoader(train_dataset, shuffle=True)
test_loader = DataLoader(test_dataset, shuffle=False)

# %%
model = m.MLPmodel(784,10,10)
criterion = nn.CrossEntropyLoss()
optimizer = optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay= 1e-5)
m.train_model(model,criterion, optimizer, train_loader,test_loader)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 criterion = nn.CrossEntropyLoss()
#       3 optimizer = optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay= 1e-5)
# ----> 4 m.train_model(model,criterion, optimizer, train_loader,test_loader)
#
# File ~/Documents/VSCode/balance_arduino/tinyMLP/model.py:87, in train_model(model, criterion, optimizer, train_loader, test_loader, num_epochs)
#      85     current_test_loss += loss.item()
#      86     preds = torch.argmax(outputs, dim=1)
# ---> 87     all_test_preds.append(preds.numpy())
#      88     all_test_labels.append(labels.numpy())
#      90 for inputs, labels in train_loader:
#
# KeyboardInterrupt:
